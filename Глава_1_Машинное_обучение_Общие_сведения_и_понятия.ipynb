# %% [markdown]
# <a href="https://colab.research.google.com/github/itonsoup/Google-Colab/blob/main/%D0%93%D0%BB%D0%B0%D0%B2%D0%B0_1_%D0%9C%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%B5_%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5_%D0%9E%D0%B1%D1%89%D0%B8%D0%B5_%D1%81%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B8_%D0%BF%D0%BE%D0%BD%D1%8F%D1%82%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Контрольные вопросы

# %% [markdown]
# ## 1. Какие числовые признаки называются дискретными, а какие — непрерывными? Приведите собственные примеры.

# %% [markdown]
# Ответ:

# %% [markdown]
# Числовые признаки:
#
# Дискретные признаки принимают ограниченное число значений и могут быть перечислены.
#
# Пример: количество комнат в квартире (1, 2, 3 и т.д.), количество автомобилей у человека.
#
# Непрерывные признаки могут принимать любые значения в пределах определенного диапазона.
#
# Пример: рост человека в сантиметрах, вес автомобиля в килограммах.

# %% [markdown]
# ## 2. Опишите разницу между обучением с учителем и обучением без учителя.

# %% [markdown]
# Ответ:

# %% [markdown]
# Обучение с учителем предполагает наличие размеченных данных (входных данных и соответствующих меток), на которых алгоритм обучается, чтобы предсказывать метки для новых данных.
#
# Обучение без учителя используется, когда данные не размечены, и алгоритм должен выявлять структуры или паттерны самостоятельно. Например, кластеризация или понижение размерности.

# %% [markdown]
# ## 3. Опишите разницу между задачами классификации и регрессии.

# %% [markdown]
# Ответ:

# %% [markdown]
# Классификация — это задача, где модель предсказывает категориальные метки (например, класс объекта: мужчина или женщина).
#
# Регрессия предсказывает непрерывное значение (например, предсказание цены недвижимости).

# %% [markdown]
# ## 4. Если вас попросят создать программу, которая будет определять кошку или собаку по изображению, к какому типу задач машинного обучения относится эта просьба?

# %% [markdown]
# Ответ:

# %% [markdown]
# Определение, является ли изображение кошкой или собакой — это задача классификации. Модель должна выбирать из двух классов (кошка или собака).

# %% [markdown]
# ## 5. Почему в качестве альтернативы простому использованию всех тренировочных данных рекомендуется выполнять проверку модели на валидационных данных?

# %% [markdown]
# Ответ:

# %% [markdown]
# Использование валидационных данных позволяет проверять модель на данные, которые она не видела во время обучения. Это помогает избежать переобучения (когда модель слишком хорошо запоминает обучающие данные, но плохо обобщает на новые примеры) и оценить ее способность к обобщению.

# %% [markdown]
# ## 6. Даны три матрицы A, B, C. Матрица A имеет размеры 5 × 4, B — размеры 4 × 6, C имеет размеры 3 × 5. Укажите все возможные матрицы, которые можно перемножить между собой.

# %% [markdown]
# Ответ:

# %% [markdown]
# Возможны следующие варианты умножения матриц:
#
# 𝐴×𝐵 (размер 5 × 6, так как число столбцов A = число строк B),
#
# 𝐶×𝐴 (размер 3 × 4, так как число столбцов C = число строк A).

# %% [markdown]
# ## ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ответ:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ответ:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ответ:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
